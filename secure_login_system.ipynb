# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedelguendy/secure-user-auth-sqlite/blob/main/secure_login_system.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3
import hashlib
import os

conn = sqlite3.connect("users.db")
cursor = conn.cursor()

cursor.execute("""
    CREATE TABLE IF NOT EXISTS users (
        username TEXT UNIQUE,
        password TEXT,
        salt TEXT
    )
""")
conn.commit()

def hash_password(password, salt):
    return hashlib.sha256((password + salt).encode()).hexdigest()

def register():
    username = input("Enter username: ")
    password = input("Enter password: ")
    salt = os.urandom(16).hex()
    hashed_password = hash_password(password, salt)
    try:
        cursor.execute("INSERT INTO users(username, password, salt) VALUES(?,?,?)", (username, hashed_password, salt))
        conn.commit()
        print("User registered successfully!")
    except sqlite3.IntegrityError:
        print("Username already exists.")
    except Exception as e:
        print(f"An error occurred: {e}")

def login():
    username = input("Enter username: ")
    password = input("Enter password: ")
    cursor.execute("SELECT salt, password FROM users WHERE username=?", (username,))
    result = cursor.fetchone()

    if result:
        salt, stored_hashed_password = result
        user_hashed_password = hash_password(password, salt)
        if user_hashed_password == stored_hashed_password:
            print("Login successful!")
        else:
            print("Invalid password.")
    else:
        print("User not found.")

while True:
    print("\n1. Register")
    print("2. Login")
    print("3. Exit")
    choice = input("Enter your choice: ")

    if choice == "1":
        register()
    elif choice == "2":
        login()
    elif choice == "3":
        break
# Out:
# 1. Register
# 2. Login
# 3. Exit
# Enter your choice: 1
# Enter username: mo
# Enter password: 1234
# User registered successfully!
#
# 1. Register
# 2. Login
# 3. Exit
# Enter your choice: login
#
# 1. Register
# 2. Login
# 3. Exit
# Enter your choice: 2
# Enter username: mo
# Enter password: 2124
# Invalid password.
#
# 1. Register
# 2. Login
# 3. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_21361/3683055183.py in <cell line: 0>()
#      53     print("2. Login")
#      54     print("3. Exit")
# ---> 55     choice = input("Enter your choice: ")
#      56
#      57     if choice == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
# ...
